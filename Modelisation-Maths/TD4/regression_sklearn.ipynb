# %% [markdown]
# # <center> TD4: Régression linéaire avec *scikit-learn* </center>

# %% [markdown]
# ### 1) Utilisation de la classe *LinearRegression* sur le jeu de données précèdent
#
# Nous allons maintenant utiliser la classe *LinearRegression* de *scikit-learn*.
# Nous allons générer le même jeu de données que précèdemment.
#
# - déterminer le modèle
# - afficher la pente de la droite obtenue et l'ordonnée à l'origine
# - afficher les résultats des calculs de l'erreur mse et rmse
# - donner une représentation graphique du jeu de données ainsi que la droite de régression.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

#TODO

# %% [markdown]
# ### 2) cas avec des caractéristiques multiples

# %% [markdown]
# Nous allons utiliser le jeu de données qui est dans *data/boston.txt*
# Ce jeu de données contient 506 échantillons et 12 variables caractéristiques. L’objectif est de prédire la valeur du prix des maisons (MEDV) en utilisant les variables caractéristiques.
#
# Voici la description des données:
#
# - CRIM : Taux de criminalité par habitant par ville.
# - ZN : Proportion de zones de terrains résidentiels pour des lots de plus de 25 000 pieds carrés.
# - INDUS : Proportion d’acres d’entreprises non commerciales par ville
# - CHAS : Variable Dummy Charles River (= 1 si la parcelle borde la rivière ; 0 sinon)
# - NOX : concentration d’oxyde nitrique (parties par 10 millions)
# - RM : Nombre moyen de pièces par logement
# - AGE : Proportion de logements occupés par leur propriétaire construits avant 1940
# - DIS : Distances pondérées par rapport à cinq centres d’emploi de Boston
# - RAD : Indice d’accessibilité aux autoroutes radiales
# - TAX : Taux d’imposition foncière sur la pleine valeur par 10 000 $
# - PTRATIO : ratio élèves/professeurs par ville
# - ACC: ratio of accident
# - LSTAT : Pourcentage de la population de statut inférieur
# - MEDV : prix des maisons occupées par leur propriétaire, en milliers de dollars

# %% [markdown]
# - Commencer par charger les données caractéristiques dans un dataframe et les données cible dans un autre dataframe. Visualiser les premières lignes pour tester que tout s'est bien passé.

# %%
df=pd.read_csv('data/boston.txt',sep='\s+',skiprows=22,header=None)
data=np.hstack([df.values[::2,:],df.values[1::2,:2]])
target = df.values[1::2,2]
columns= ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','ACC','LSTAT']
boston=pd.DataFrame(data=data,columns=columns)
boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO     ACC  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# 3       18.7  394.63   2.94
# 4       18.7  396.90   5.33
# ..       ...     ...    ...
# 501     21.0  391.99   9.67
# 502     21.0  396.90   9.08
# 503     21.0  396.90   5.64
# 504     21.0  393.45   6.48
# 505     21.0  396.90   7.88
#
# [506 rows x 13 columns]

# %% [markdown]
# Il faut maintenant pré-traiter les données (pas de valeurs nulles dans les colonnes )

# %%
boston[boston.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, ACC, LSTAT]
# Index: []

# %% [markdown]
# Dans le cas des régressions linéaires multiples, deux conditions d’application sont nécessaires:
# - il doit y avoir une relation linéaire entre chaque variable caractéristique et la variable cible.
# - les variables caractéristiques doivent être indépendantes les unes des autres (il n’y a pas de colinéarité).
#
# Nous allons construire la matrice de corrélation du jeu de donnéés qui nous montrera si des variables ont des relations de type linéaire avec la variable cible (coefficient proche de 1 ou -1).
#
#
#
# Pour cela utiliser, la méthode *corr()* de la classe *Dataframe*
# - visualiser la matrice de corrélation obtenue (on pourra utiliser la méthode de la classe Dataframe *style.background_gradient(...)*)

# %%
matrix_corr = boston.corr()
matrix_corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f71f1_row0_col0, #T_f71f1_row1_col1, #T_f71f1_row2_col2, #T_f71f1_row3_col3, #T_f71f1_row4_col4, #T_f71f1_row5_col5, #T_f71f1_row6_col6, #T_f71f1_row7_col7, #T_f71f1_row8_col8, #T_f71f1_row9_col9, #T_f71f1_row10_col10, #T_f71f1_row11_col11, #T_f71f1_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f71f1_row0_col1, #T_f71f1_row3_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f71f1_row0_col2 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_f71f1_row0_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_f71f1_row0_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_f71f1_row0_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_f71f1_row0_col6 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_f71f1_row0_col7, #T_f71f1_row11_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f71f1_row0_col8, #T_f71f1_row4_col12 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_f71f1_row0_col9, #T_f71f1_row2_col8, #T_f71f1_row8_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_f71f1_row0_col10 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_f71f1_row0_col11 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_f71f1_row0_col12 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_f71f1_row1_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_f71f1_row1_col2, #T_f71f1_row1_col6, #T_f71f1_row8_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_f71f1_row1_col3 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f71f1_row1_col4, #T_f71f1_row1_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_f71f1_row1_col5, #T_f71f1_row2_col0 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_f71f1_row1_col7, #T_f71f1_row9_col4 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_f71f1_row1_col8, #T_f71f1_row1_col12 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f71f1_row1_col10, #T_f71f1_row4_col7, #T_f71f1_row5_col12, #T_f71f1_row6_col1, #T_f71f1_row7_col0, #T_f71f1_row7_col2, #T_f71f1_row7_col4, #T_f71f1_row7_col6, #T_f71f1_row7_col8, #T_f71f1_row7_col9, #T_f71f1_row8_col11, #T_f71f1_row9_col11, #T_f71f1_row10_col3, #T_f71f1_row11_col0, #T_f71f1_row12_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f71f1_row1_col11 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_f71f1_row2_col1, #T_f71f1_row7_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col3, #T_f71f1_row8_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col4 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col6 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col7, #T_f71f1_row4_col1, #T_f71f1_row11_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col10 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_f71f1_row2_col11, #T_f71f1_row11_col9, #T_f71f1_row12_col3 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f71f1_row2_col12 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_f71f1_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_f71f1_row3_col2 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_f71f1_row3_col4, #T_f71f1_row10_col0 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_f71f1_row3_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_f71f1_row3_col6 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_f71f1_row3_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_f71f1_row3_col8, #T_f71f1_row3_col9 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_f71f1_row3_col10, #T_f71f1_row4_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f71f1_row3_col11 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_f71f1_row3_col12 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f71f1_row4_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_f71f1_row4_col2 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_f71f1_row4_col3, #T_f71f1_row5_col3, #T_f71f1_row5_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_f71f1_row4_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_f71f1_row4_col8 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_f71f1_row4_col9 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_f71f1_row4_col10 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_f71f1_row4_col11 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_f71f1_row5_col0, #T_f71f1_row6_col11 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_f71f1_row5_col1 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_f71f1_row5_col2, #T_f71f1_row6_col3, #T_f71f1_row10_col11 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f71f1_row5_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f71f1_row5_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_f71f1_row5_col7 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_f71f1_row5_col9, #T_f71f1_row10_col5 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_f71f1_row5_col10 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_f71f1_row5_col11 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_f71f1_row6_col0 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_f71f1_row6_col2 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_f71f1_row6_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_f71f1_row6_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_f71f1_row6_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_f71f1_row6_col8 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_f71f1_row6_col9 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_f71f1_row6_col10 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_f71f1_row6_col12 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_f71f1_row7_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_f71f1_row7_col5 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_f71f1_row7_col10, #T_f71f1_row10_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_f71f1_row7_col11 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_f71f1_row7_col12 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_f71f1_row8_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_f71f1_row8_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_f71f1_row8_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f71f1_row8_col6 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_f71f1_row8_col7, #T_f71f1_row11_col10, #T_f71f1_row11_col12, #T_f71f1_row12_col7 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f71f1_row8_col9 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_f71f1_row8_col10 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_f71f1_row8_col12 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_f71f1_row9_col0 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_f71f1_row9_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f71f1_row9_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_f71f1_row9_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_f71f1_row9_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_f71f1_row9_col6, #T_f71f1_row9_col12 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_f71f1_row9_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_f71f1_row9_col8 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_f71f1_row9_col10, #T_f71f1_row10_col12 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_f71f1_row10_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_f71f1_row10_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_f71f1_row10_col6 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_f71f1_row10_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f71f1_row10_col8 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_f71f1_row10_col9 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_f71f1_row11_col1 {
#   background-

# %% [markdown]
# - Rechercher les variables qui sont les plus corrélées linéairement avec le prix (MEDV)
# - pour chacune de ces variables représenter graphiquement le prix en fonction d'une variable choisie. Que constatez vous ?

# %%
#TODO

# %% [markdown]
# Mettre en place la régression linéaire qui prend en compte les variables précédentes.
# Vous allez d'abord séparer le jeu de données en 80% d'apprentissage et 20% de test

# %%
#TODO

# %% [markdown]
# - réaliser l'apprentissage de la droite de régression sur l'ensemble d'apprentissage et réaliser une prédiction sur ce même ensemble d'apprentissage.
# - regarder en quoi consiste les mesures nommées, **coefficient de détermination: r_squared(r2)**, **l'erreur quadratique moyenne (mse)**, **racine de l'erreur quadratique (rmse)**
# - utiliser **rmse** et **r-squared** pour déterminer les performances du modèle sur les données d'apprentissage

# %%
#TODO

# %% [markdown]
# Réaliser la prédiction sur l'ensemble de test et afficher les scores *rmse* et *r_squared(r2)*

# %%
#TODO
